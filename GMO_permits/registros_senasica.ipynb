# %%
import pandas as pd

# %%
reg_2018 = pd.read_excel('Registro2018.xls')

# %%
reg_2018
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001_2018                                    2018-02-14
# 1   002_2018                                    2018-02-27
# 2   003_2018                                    2018-02-27
# 3   004_2018                                    2018-03-06
# 4   005_2018                                    2018-03-26
# 5   006_2018                                    2018-03-26
# 6   007_2018                                    2018-06-20
# 7   008_2018                                    2018-06-20
# 8   009_2018                                    2018-06-20
# 9   010_2018                                    2018-06-20
# 10  011_2018                                    2018-06-20
# 11  012_2018                                    2018-06-20
# 12  013_2018                                    2018-06-20
# 13  014_2018                                    2018-08-09
# 14  015_2018                                    2018-08-09
# ...

# %%
reg_2017 = pd.read_excel('Registro2017.xls')
reg_2017
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001/2017                                    2017-03-03
# 1   002/2017                                    2017-05-23
# 2   003/2017                                    2017-05-23
# 3   004/2017                                    2017-05-23
# 4   005/2017                                    2017-05-23
# 5   007/2017                                    2017-05-29
# 6   010/2017                                    2017-07-20
# 7   011/2017                                    2017-07-20
# 8   012/2017                                    2017-07-20
# 9   013/2017                                    2017-07-20
# 10  014/2017                                    2017-07-28
# 11  015/2017                                    2017-07-28
# 12  016/2017                                    2017-08-08
# 13  017/2017                                    2017-08-08
# 14  018/2017                                    2017-08-08
# ...

# %%
reg_2016 = pd.read_excel('Registro2016.xls')
reg_2016
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   011/2016                                    2016-07-28
# 1   012/2016                                    2016-07-28
# 2   013/2016                                    2016-08-15
# 3   014/2016                                    2016-08-29
# 4   015/2016                                    2016-09-09
# 5   016/2016                                    2016-09-09
# 6   017/2016                                    2016-08-29
# 7   018/2016                                    2016-08-15
# 8   019/2016                                    2016-08-15
# 9   020/2016                                    2016-08-29
# 10  021/2016                                    2016-09-27
# 11  022/2016                                    2016-09-27
# 12  023/2016                                    2016-08-29
# 13  024/2016                                    2016-08-29
# 14  025/2016                                    2016-08-30
# ...

# %%
reg_2015 = pd.read_excel('Registro2015.xls')
reg_2015
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001/2015                                    2015-03-30
# 1   002/2015                                    2015-03-30
# 2   003/2015                                    2015-04-13
# 3   004/2015                                    2015-04-16
# 4   005/2015                                    2015-04-20
# 5   006/2015                                    2015-07-28
# 6   007/2015                                    2015-07-28
# 7   008/2015                                    2015-08-05
# 8   009/2015                                    2015-08-05
# 9   010/2015                                    2015-08-05
# 10  011/2015                                    2015-08-24
# 11  012/2015                                    2015-08-24
# 12  013/2015                                    2015-08-24
# 13  014/2015                                    2015-08-21
# 14  015/2015                                    2015-10-07
# ...

# %%
reg_2014 = pd.read_excel('Registro2014.xls')
reg_2014
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   002/2014                                    2014-05-16
# 1   003/2014                                    2014-05-16
# 2   007/2014                                    2014-06-04
# 3   008/2014                                    2014-06-23
# 4   009/2014                                    2014-06-23
# 5   010/2014                                    2014-06-23
# 6   011/2014                                    2014-06-23
# 7   012/2014                                    2014-06-23
# 8   013/2014                                    2014-06-23
# 9   014/2014                                    2014-06-23
# 10  015/2014                                    2014-07-24
# 11  016/2014                                    2014-07-24
# 12  017/2014                                    2014-08-25
# 13  018/2014                                    2014-08-25
# 14  019/2014                                    2014-08-25
# ...

# %%
reg_2013 = pd.read_excel('Registro2013.xls')
reg_2013
# Out:
#     SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001/2008                           2008-02-19 00:00:00
# 1   002/2008                           2008-02-19 00:00:00
# 2   003/2008                           2008-02-19 00:00:00
# 3   004/2008                           2008-02-19 00:00:00
# 4   005/2008                           2008-02-19 00:00:00
# 5   006/2008                           2008-02-19 00:00:00
# 6   007/2008                           2008-08-01 00:00:00
# 7   008/2008                           2008-08-01 00:00:00
# 8   009/2008                           2008-08-01 00:00:00
# 9   010/2008                           2008-08-01 00:00:00
# 10  011/2008                           2008-08-01 00:00:00
# 11  012/2008                           2008-09-04 00:00:00
# 12  013/2008                           2008-09-04 00:00:00
# 13  014/2008                           2008-10-01 00:00:00
# 14  015/2008                           2008-10-01 00:00:00
# ...

# %%
reg_2007 = pd.read_excel('Registro2007.xls')
reg_2007
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001/2007                                    2007-01-19
# 1   002/2007                                    2007-01-19
# 2   003/2007                                    2007-06-15
# 3   004/2007                                    2007-06-15
# 4   005/2007                                    2007-06-15
# 5   006/2007                                    2007-06-15
# 6   007/2007                                    2007-06-15
# 7   008/2007                                    2007-06-15
# 8   009/2007                                    2007-06-15
# 9   010/2007                                    2007-06-15
# 10  011/2007                                    2007-05-30
# 11  012/2007                                    2007-05-30
# 12  013/2007                                    2007-05-30
# 13  014/2007                                    2007-08-16
# 14  015/2007                                    2007-08-16
# ...

# %%
reg_2006 = pd.read_excel('Registro2006.xls')
reg_2006
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001/2006                           2006-01-13 00:00:00
# 1   002/2006                                     Sin dato.
# 2   003/2006                           2006-01-26 00:00:00
# 3   004/2006                           2006-02-01 00:00:00
# 4   005/2006                           2006-02-03 00:00:00
# 5   006/2006                           2006-02-03 00:00:00
# 6   007/2006                           2006-02-23 00:00:00
# 7   008/2006                           2006-02-24 00:00:00
# 8   009/2006                           2006-03-06 00:00:00
# 9   010/2006                           2006-03-09 00:00:00
# 10  011/2006                                 Sin Registro.
# 11  012/2006                                 Sin Registro.
# 12  013/2006                           2006-05-19 00:00:00
# 13  014/2006                           2006-04-20 00:00:00
# 14  015/2006                           2006-04-20 00:00:00
# ...

# %%
reg_2005 = pd.read_excel('Registro2005.xls')
reg_2005
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001/2005                                      Sin dato
# 1   002/2005                                      Sin dato
# 2   003/2005                                      Sin dato
# 3   004/2005                                      Sin dato
# 4   005/2005                                      Sin dato
# 5   006/2005                                      Sin dato
# 6   007/2005                                  Sin registro
# 7   008/2005                                  Sin registro
# 8   009/2005                                      Sin dato
# 9   010/2005                                      Sin dato
# 10  011/2005                                      Sin dato
# 11  012/2005                           2005-05-25 00:00:00
# 12  013/2005                           2005-05-25 00:00:00
# 13  014/2005                           2005-05-25 00:00:00
# 14  015/2005                           2005-05-25 00:00:00
# ...

# %%
frames = [reg_2018, reg_2017, reg_2016, reg_2015, reg_2014, reg_2013, reg_2012, reg_2011, reg_2010, reg_2009, reg_2008, reg_2007, reg_2006, reg_2005]

# %%
df = pd.concat(frames, sort=False)

# %%
df
# Out:
#    SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0   001_2018                           2018-02-14 00:00:00
# 1   002_2018                           2018-02-27 00:00:00
# 2   003_2018                           2018-02-27 00:00:00
# 3   004_2018                           2018-03-06 00:00:00
# 4   005_2018                           2018-03-26 00:00:00
# 5   006_2018                           2018-03-26 00:00:00
# 6   007_2018                           2018-06-20 00:00:00
# 7   008_2018                           2018-06-20 00:00:00
# 8   009_2018                           2018-06-20 00:00:00
# 9   010_2018                           2018-06-20 00:00:00
# 10  011_2018                           2018-06-20 00:00:00
# 11  012_2018                           2018-06-20 00:00:00
# 12  013_2018                           2018-06-20 00:00:00
# 13  014_2018                           2018-08-09 00:00:00
# 14  015_2018                           2018-08-09 00:00:00
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 0    001_2018                           2018-02-14 00:00:00
# 1    002_2018                           2018-02-27 00:00:00
# 2    003_2018                           2018-02-27 00:00:00
# 3    004_2018                           2018-03-06 00:00:00
# 4    005_2018                           2018-03-26 00:00:00
# 5    006_2018                           2018-03-26 00:00:00
# 6    007_2018                           2018-06-20 00:00:00
# 7    008_2018                           2018-06-20 00:00:00
# 8    009_2018                           2018-06-20 00:00:00
# 9    010_2018                           2018-06-20 00:00:00
# 10   011_2018                           2018-06-20 00:00:00
# 11   012_2018                           2018-06-20 00:00:00
# 12   013_2018                           2018-06-20 00:00:00
# 13   014_2018                           2018-08-09 00:00:00
# 14   015_2018                           2018-08-09 00:00:00
# ...

# %%
df['PROMOVENTE'].value_counts()
# Out:
# Monsanto Comercial, S.A. de C.V.                                                                    147
# Bayer de México, S.A. de C.V.                                                                       109
# PHI México, S.A. de C.V.                                                                             85
# Monsanto Comercial S.A. de C.V.                                                                      66
# Syngenta Agro, S.A. de C.V.                                                                          52
# Bayer de México S.A. de C.V.                                                                         48
# Semillas y Agroproductos Monsanto, S.A. de C.V.                                                      38
# Bayer de México, S.A. de C.V. División CropScience                                                   35
# PHI México, S.A. de C.V. / Dow AgroSciences de México, S.A. de C.V.                                  30
# ...

# %%
pd.set_option('max_colwidth', 800)

# %%
df[df["ESTADO"].str.contains("Cam")]
# Out:
#     SOLICITUD FECHA DE RECEPCIÓN EN LA SECRETARÍA EJECUTIVA  \
# 227  090/2013                           2013-12-12 00:00:00
# 237  007/2012                           2012-02-29 00:00:00
# 349  014/2011                           2011-03-16 00:00:00
# 477  009/2010                                    28/04/2010
# 664  002/2008                           2008-02-19 00:00:00
# 715  077/2008                           2009-01-07 00:00:00
# 727  010/2007                           2007-06-15 00:00:00
# 781  008/2006                           2006-02-24 00:00:00
#
#                                           PROMOVENTE      IU OCDE  \
# 227                     Bayer de México S.A. de C.V.  ACS-GMØØ6-4
# 237                 Monsanto Comercial, S.A. de C.V.  MON-Ø4Ø32-6
# 349                 Monsanto Comercial, S.A. de C.V.  MON-Ø4Ø32-6
# 477                 Monsanto Comercial, S.A. de C.V.          NaN
# 664  Semillas y Agroproductos Monsanto S.A. de C.V.           NaN
# ...

# %%
df = pd.read_csv("OGMs (21-06-18).csv", encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-32-0e011192818f> in <module>()
# ----> 1 df = pd.read_csv("OGMs (21-06-18).csv", encoding='latin-1')
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df
# Out:
#                                 Estatus,Aï¿½o de Recepciï¿½n,Fecha de Recepciï¿½n,Solicitud,Fase,Promovente,Cultivo,Evento,Estado,Vigencia,Superficie Solicitada (ha),Superficie Permitida (ha)
# 0                                   ,2018,2018-01-26,001_2018,Experimental ,Bayer de Mï¿½xico, S.A. de C.V.,Algodï¿½n,BCS-GH002-5 x BCS-GH004-7 x BCS-GH005-8,Tamaulipas,P-V 2018,1.5,No aplica
# 1                       ,2018,2018-02-07,002_2018,Piloto ,Monsanto Comercial, S. de R.L. de C.V.,Algodï¿½n,MON-15985-7 x SYN-IR102-7 x MON-88913-8 x MON-88701-3,Sinaloa,O-I 2018,9.0,No aplica
# 2                                                   ,2018,2018-02-07,003_2018,Piloto ,Monsanto Comercial, S. de R.L. de C.V.,Algodï¿½n,MON-88913-8 x MON-88701-3,Sinaloa,O-I 2018,9.0,No aplica
# 3                      ,2018,2018-02-13,004_2018,Piloto ,Bayer de Mï¿½xico, S.A. de C.V.,Algodï¿½n,BCS-GH002-5 x ACS-GH001-3 ,Tamaulipas, San Luis Potosï¿½ y Veracruz,P-V 2018,350.0,No aplica
# ...
